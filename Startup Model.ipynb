# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Load the data 
data=pd.read_csv('50_Startups_LR.csv')

# %%
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data['State'].unique
# Out:
# <bound method Series.unique of 0       New York
# 1     California
# 2        Florida
# 3       New York
# 4        Florida
# 5       New York
# 6     California
# 7        Florida
# 8       New York
# 9     California
# 10       Florida
# 11    California
# 12       Florida
# 13    California
# 14       Florida
# 15      New York
# 16    California
# 17      New York
# 18       Florida
# 19      New York
# 20    California
# 21      New York
# 22       Florida
# 23       Florida
# 24      New York
# 25    California
# 26       Florida
# 27      New York
# 28       Florida
# 29      New York
# 30       Florida
# 31      New York
# 32    California
# 33       Florida
# 34    California
# 35      New York
# 36       Florida
# 37    California
# 38      New York
# 39    California
# 40    California
# 41       Florida
# 42    California
# 43      New York
# 44    California
# 45      New York
# 46       Florida
# 47    California
# 48      New York
# 49    California
# ...

# %%
y=['Florida','New York','California']
state_sum=data.groupby('State').sum()
print(state_sum)
# Out:
#              R&D Spend  Administration  Marketing Spend      Profit
# State
# California  1099180.46      2052690.62       3103195.80  1766387.98
# Florida     1291584.26      1948302.36       3957176.82  1900384.39
# New York    1295316.06      2066239.00       3490882.27  1933859.59

# %% [markdown]
# ## Domain Analysis

# %% [raw]
# R&D spend : this help company to innovate and improve their poducts and brings new insights according to future use and market needs.
#
# Administration : A well-structured administration function in a startup ensures legal safety, cost control, smooth operations, and scalability. While early-stage startups may not need a full-fledged admin team, assigning administrative responsibilities to a co-founder or hiring an Office Manager/Operations Executive can prevent future bottlenecks.
#
# Marketing Spend : Marketing in a startup is not just about ads—it’s about finding the right audience, converting them efficiently, and retaining them profitably. A lean, data-driven approach helps startups scale without burning cash.

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# ### Statistical Analysis

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %% [raw]
# Minimum spent on R&D and Marketing but spent on Administration is mandatory.
# maximum spread of data in Marketing.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [raw]
# There is no null data, and one object
# Profit is the the output(y) and all other columns are input (x) except State

# %% [markdown]
# ### Visulaization

# %%
# univariat analysis

# %%
plt.figure(figsize=(20,30),facecolor='White')
plotnumuber=1

for column in data:
    if(plotnumuber<=9):
        ax=plt.subplot(3,3,plotnumuber)
        sns.histplot(data[column],kde=True)
        plt.xlabel(column, fontsize=25)
        plt.ylabel('Count',fontsize=25)
    plotnumuber+=1
plt.tight_layout()

# %% [raw]
# R&D spend: more than 10 people spend 75000, 4 company spent on 100000.
#
# Administration: data is partially normal distributed.
#
# State: data's distribution is balanced.
#
# Profit : normal distribution curve

# %%
# Bivariate analysis

# %%
sns.scatterplot(x='R&D Spend', y='Profit', hue='State', data=data)
# Out:
# <Axes: xlabel='R&D Spend', ylabel='Profit'>

# %% [raw]
# Positive linear relationship between both. some statup spent 0 but still generate pofit but as spent increase profit is also increases.

# %%
sns.scatterplot(x='Administration', y='Profit', hue='State', data=data)
# Out:
# <Axes: xlabel='Administration', ylabel='Profit'>

# %% [raw]
# There is no clear relation between the two, but if we generalize the majority of data, when the administration spent more than 80000, then the majority of companies secured a profit of more than 75000. Some exceptions also exist, such as spending 120000 in administration but securing a profit of less than 25000.

# %%
sns.scatterplot(x='Marketing Spend', y='Profit', hue='State', data=data)
# Out:
# <Axes: xlabel='Marketing Spend', ylabel='Profit'>

# %% [raw]
# There is a linear relation between both but some exceptions existed after 200000 spending in marketing there is sudden reduction in profits.

# %%
plt.figure(figsize=(20,25))
sns.pairplot(data,hue='State')
plt.tight_layout()

# %% [raw]
# R&D spend and Marketing spend has linear relationship.

# %% [markdown]
# ## Data Preprocessing and Feature Engineering.

# %%
# find if null value exist
data.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
# Handling corrupt data.

# %%
# identify outliers
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in data:
    if plotnumber<=5:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize=30)
        plt.ylabel('Count',fontsize=30)
    plotnumber=plotnumber+1
plt.tight_layout()

# %% [raw]
# Data has no outliers.

# %%
## Step 5: Scaling the data.

# %% [markdown]
# ## Feature Selection

# %%
## No reduntant feature 
## we will check correlation
data1=data.drop('State',axis=1)
sns.heatmap(data1.corr(),annot=True)
# Out:
# <Axes: >

# %%
x=data1.iloc[:,:-1]
y=data1.Profit

# %%
## Step 2 Creating independent and dependent Varibale.
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=12)

# %%
y_train
# Out:
# 15    129917.04
# 31     97483.56
# 14    132602.65
# 26    105733.54
# 9     149759.96
# 33     96778.92
# 47     42559.73
# 20    118474.03
# 16    126992.93
# 24    108552.04
# 42     71498.49
# 32     97427.84
# 35     96479.51
# 23    108733.99
# 1     191792.06
# 30     99937.59
# 4     166187.94
# 44     65200.33
# 39     81005.76
# 18    124266.90
# 40     78239.91
# 43     69758.98
# 0     192261.83
# 10    146121.95
# 49     14681.40
# 34     96712.80
# 25    107404.34
# 13    134307.35
# 5     156991.12
# 22    110352.25
# 12    141585.52
# 45     64926.08
# 3     182901.99
# 2     191050.39
# 6     156122.51
# 27    105008.31
# 11    144259.40
# Name: Profit, dtype: float64

# %%
y_test
# Out:
# 28    103282.38
# 46     49490.75
# 7     155752.60
# 41     77798.83
# 36     90708.19
# 29    101004.64
# 21    111313.02
# 48     35673.41
# 19    122776.86
# 8     152211.77
# 17    125370.37
# 38     81229.06
# 37     89949.14
# Name: Profit, dtype: float64

# %%
# Step 3 Model Creation
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR.predict(x_test)

# %%
y_pred
# Out:
# array([100741.3307628 ,  56435.61048905, 159846.5995856 ,  75035.62401062,
#         75177.29348594, 101149.00888754, 117089.72567306,  49400.16082318,
#        114703.78606791, 151522.31744387, 129984.29236472,  70179.22099208,
#         90237.3866699 ])

# %%
y_test
# Out:
# 28    103282.38
# 46     49490.75
# 7     155752.60
# 41     77798.83
# 36     90708.19
# 29    101004.64
# 21    111313.02
# 48     35673.41
# 19    122776.86
# 8     152211.77
# 17    125370.37
# 38     81229.06
# 37     89949.14
# Name: Profit, dtype: float64

# %%
LR.coef_
# Out:
# array([ 0.80410637, -0.03685865,  0.02953472])

# %%
LR.intercept_
# Out:
# np.float64(50871.47770576642)

# %%
# For User Inputs
RD=int(input('Spend on R&D:'))
Adm=int(input('Spend on Administration :'))
Mar=int(input('Spend on Marketing :'))
Profit= 0.80410637*RD +(-0.03685865*Adm) +0.02953472*Mar+50871.47770576642
print(Profit,':is the estimated Profit')
# Out:
# Spend on R&D: 457777
# Spend on Administration : 561144
# Spend on Marketing : 15562222
# 857915.7384974965 :is the estimated Profit

# %%
y_test
# Out:
# 28    103282.38
# 46     49490.75
# 7     155752.60
# 41     77798.83
# 36     90708.19
# 29    101004.64
# 21    111313.02
# 48     35673.41
# 19    122776.86
# 8     152211.77
# 17    125370.37
# 38     81229.06
# 37     89949.14
# Name: Profit, dtype: float64

# %%
y_pred
# Out:
# array([100741.3307628 ,  56435.61048905, 159846.5995856 ,  75035.62401062,
#         75177.29348594, 101149.00888754, 117089.72567306,  49400.16082318,
#        114703.78606791, 151522.31744387, 129984.29236472,  70179.22099208,
#         90237.3866699 ])

# %%
# Steps 4 Model Evaluation
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2score=r2_score(y_test,y_pred)

# %%
r2score
# Out:
# 0.949437498799158

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   Profit           50 non-null     float64
# dtypes: float64(4)
# memory usage: 1.7 KB

# %%
# Adjusted r2score: 
Ar2=1-((1-0.949437498799158)*(49-1)/(49-3-1))
Ar2
# Out:
# 0.9460666653857684

# %%
import math
print(mean_squared_error(y_test,y_pred))
# Out:
# 57786764.55825901

# %%
print(math.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 7601.760622267648

# %%
print(mean_absolute_error(y_test,y_pred))
# Out:
# 5864.336286910265
