# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('synthetic_asthma_dataset.csv')

# %%
df.head(200)
# Out:
#      Patient_ID  Age  Gender   BMI Smoking_Status  Family_History Allergies  \
# 0    ASTH100000   52  Female  27.6         Former               1       NaN
# 1    ASTH100001   15    Male  24.6         Former               0      Dust
# 2    ASTH100002   72  Female  17.6          Never               0       NaN
# 3    ASTH100003   61    Male  16.8          Never               0  Multiple
# 4    ASTH100004   21    Male  30.2          Never               0       NaN
# ..          ...  ...     ...   ...            ...             ...       ...
# 195  ASTH100195   39    Male  25.0        Current               1    Pollen
# 196  ASTH100196    2  Female  33.7        Current               0       NaN
# 197  ASTH100197    3  Female  18.1        Current               0      Dust
# 198  ASTH100198   56    Male  15.0          Never               0       NaN
# 199  ASTH100199   81  Female  27.7         Former               0      Pets
#
# ...

# %% [raw]
# object= Gender, Smoking_Status, Allergies, Air_Pollution_Level, Physical_Activity_Level, Occupation_Type, Comorbidities, Asthma_Control_Level.
#
# null= Allergies,Comorbidities, Asthma_Control_Level.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Patient_ID               10000 non-null  object
#  1   Age                      10000 non-null  int64
#  2   Gender                   10000 non-null  object
#  3   BMI                      10000 non-null  float64
#  4   Smoking_Status           10000 non-null  object
#  5   Family_History           10000 non-null  int64
#  6   Allergies                7064 non-null   object
#  7   Air_Pollution_Level      10000 non-null  object
#  8   Physical_Activity_Level  10000 non-null  object
#  9   Occupation_Type          10000 non-null  object
#  10  Comorbidities            5033 non-null   object
#  11  Medication_Adherence     10000 non-null  float64
#  12  Number_of_ER_Visits      10000 non-null  int64
#  13  Peak_Expiratory_Flow     10000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Age           BMI  Family_History  Medication_Adherence  \
# count  10000.000000  10000.000000    10000.000000          10000.000000
# mean      44.930700     25.053320        0.303400              0.497998
# std       25.653559      4.874466        0.459749              0.224809
# min        1.000000     15.000000        0.000000              0.000000
# 25%       23.000000     21.600000        0.000000              0.320000
# 50%       45.000000     25.000000        0.000000              0.500000
# 75%       67.000000     28.400000        1.000000              0.670000
# max       89.000000     45.000000        1.000000              0.990000
#
#        Number_of_ER_Visits  Peak_Expiratory_Flow    FeNO_Level    Has_Asthma
# count         10000.000000          10000.000000  10000.000000  10000.000000
# mean              1.015900            400.884090     25.101420      0.243300
# std               1.020564             97.531113      9.840184      0.429096
# ...

# %%
df.describe(include ='O')
# Out:
#         Patient_ID  Gender Smoking_Status Allergies Air_Pollution_Level  \
# count        10000   10000          10000      7064               10000
# unique       10000       3              3         4                   3
# top     ASTH100000  Female          Never      Dust            Moderate
# freq             1    4814           6070      2479                4915
#
#        Physical_Activity_Level Occupation_Type Comorbidities  \
# count                    10000           10000          5033
# unique                       3               2             3
# top                  Sedentary          Indoor      Diabetes
# freq                      4062            7035          2029
#
#        Asthma_Control_Level
# count                  2433
# unique                    3
# top          Not Controlled
# freq                   1229

# %% [markdown]
# ## Data Visulization

# %%
import sweetviz as sv
my_report = sv.analyze(df)
my_report.show_notebook()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
plt.figure(figsize=(20,25), facecolor='white')
i=1
for column in df.columns:
    ax=plt.subplot(5,4,i)
    sns.histplot(x=df[column], kde=True)
    plt.xlabel(column,fontsize=20)
    i=i+1
plt.show()

# %%
plt.figure(figsize=(20,25), facecolor='white')
i=1
for column in df.columns:
    ax=plt.subplot(5,4,i)    # this vlues changes according to the no. of columns
    sns.histplot(x=df[column],hue=df.Has_Asthma)
    plt.xlabel(column,fontsize=20)
    plt.ylabel('Has_Asthma',fontsize=20)
    i=i+1
plt.show()
# Out:
# C:\Users\Pranav Gupta\anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##  Handeling Null Values

# %%
df.isna().sum()
# Out:
# Patient_ID                    0
# Age                           0
# Gender                        0
# BMI                           0
# Smoking_Status                0
# Family_History                0
# Allergies                  2936
# Air_Pollution_Level           0
# Physical_Activity_Level       0
# Occupation_Type               0
# Comorbidities              4967
# Medication_Adherence          0
# Number_of_ER_Visits           0
# Peak_Expiratory_Flow          0
# FeNO_Level                    0
# Has_Asthma                    0
# Asthma_Control_Level       7567
# dtype: int64

# %%
df['Allergies'] = df['Allergies'].fillna(df['Allergies'].mode()[0])
df['Comorbidities'] = df['Comorbidities'].fillna(df['Comorbidities'].mode()[0])
df['Asthma_Control_Level'] = df['Asthma_Control_Level'].fillna(df['Asthma_Control_Level'].mode()[0])

# %%
df.isna().sum()
# Out:
# Patient_ID                 0
# Age                        0
# Gender                     0
# BMI                        0
# Smoking_Status             0
# Family_History             0
# Allergies                  0
# Air_Pollution_Level        0
# Physical_Activity_Level    0
# Occupation_Type            0
# Comorbidities              0
# Medication_Adherence       0
# Number_of_ER_Visits        0
# Peak_Expiratory_Flow       0
# FeNO_Level                 0
# Has_Asthma                 0
# Asthma_Control_Level       0
# dtype: int64

# %%
df
# Out:
#       Patient_ID  Age  Gender   BMI Smoking_Status  Family_History Allergies  \
# 0     ASTH100000   52  Female  27.6         Former               1      Dust
# 1     ASTH100001   15    Male  24.6         Former               0      Dust
# 2     ASTH100002   72  Female  17.6          Never               0      Dust
# 3     ASTH100003   61    Male  16.8          Never               0  Multiple
# 4     ASTH100004   21    Male  30.2          Never               0      Dust
# ...          ...  ...     ...   ...            ...             ...       ...
# 9995  ASTH109995   70    Male  25.0          Never               0      Dust
# 9996  ASTH109996   78  Female  24.8          Never               0    Pollen
# 9997  ASTH109997   58    Male  30.1         Former               1    Pollen
# 9998  ASTH109998   88  Female  31.2         Former               0    Pollen
# 9999  ASTH109999   13  Female  16.4         Former               1  Multiple
#
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    4814
# Male      4786
# Other      400
# Name: count, dtype: int64

# %%
df['Gender'] = df['Gender'].replace('Other', df['Gender'].mode()[0])

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    5214
# Male      4786
# Name: count, dtype: int64

# %% [markdown]
# ## Handeling Catagorical Values

# %%
cata_df = df.select_dtypes(include ='O').columns
cata_df
# Out:
# Index(['Patient_ID', 'Gender', 'Smoking_Status', 'Allergies',
#        'Air_Pollution_Level', 'Physical_Activity_Level', 'Occupation_Type',
#        'Comorbidities', 'Asthma_Control_Level'],
#       dtype='object')

# %%
for i in cata_df:
    print(i,df[i].unique())
    print(df[i].value_counts())
    print('**********************')
# Out:
# Patient_ID ['ASTH100000' 'ASTH100001' 'ASTH100002' ... 'ASTH109997' 'ASTH109998'
#  'ASTH109999']
# Patient_ID
# ASTH100000    1
# ASTH106670    1
# ASTH106663    1
# ASTH106664    1
# ASTH106665    1
#              ..
# ASTH103333    1
# ASTH103334    1
# ASTH103335    1
# ASTH103336    1
# ASTH109999    1
# Name: count, Length: 10000, dtype: int64
# **********************
# Gender ['Female' 'Male']
# Gender
# Female    5214
# Male      4786
# Name: count, dtype: int64
# **********************
# Smoking_Status ['Former' 'Never' 'Current']
# Smoking_Status
# Never      6070
# Former     2487
# Current    1443
# Name: count, dtype: int64
# **********************
# Allergies ['Dust' 'Multiple' 'Pollen' 'Pets']
# Allergies
# Dust        5415
# Pollen      1999
# Pets        1585
# Multiple    1001
# Name: count, dtype: int64
# **********************
# Air_Pollution_Level ['Moderate' 'Low' 'High']
# Air_Pollution_Level
# Moderate    4915
# Low         2984
# High        2101
# ...

# %%
# Smoking_Status
df.loc[df['Smoking_Status']=='Never','Smoking_Status']=0
df.loc[df['Smoking_Status']=='Former','Smoking_Status']=1
df.loc[df['Smoking_Status']=='Current','Smoking_Status']=2

# Allergies
df.loc[df['Allergies']=='Dust','Allergies']=3
df.loc[df['Allergies']=='Pollen','Allergies']=2
df.loc[df['Allergies']=='Pets','Allergies']=1
df.loc[df['Allergies']=='Multiple','Allergies']=0

# Air_Pollution_Level
df.loc[df['Air_Pollution_Level']=='Moderate','Air_Pollution_Level']=2
df.loc[df['Air_Pollution_Level']=='Low','Air_Pollution_Level']=1
df.loc[df['Air_Pollution_Level']=='High','Air_Pollution_Level']=0

# Physical_Activity_Level
df.loc[df['Physical_Activity_Level']=='Sedentary','Physical_Activity_Level']=2
df.loc[df['Physical_Activity_Level']=='Moderate','Physical_Activity_Level']=1
df.loc[df['Physical_Activity_Level']=='Active','Physical_Activity_Level']=0

# Occupation_Type
df.loc[df['Occupation_Type']=='Indoor','Occupation_Type']=0
df.loc[df['Occupation_Type']=='Outdoor','Occupation_Type']=1

# Comorbidities
df.loc[df['Comorbidities']=='Diabetes','Comorbidities']=2
df.loc[df['Comorbidities']=='Hypertension','Comorbidities']=1
df.loc[df['Comorbidities']=='Both','Comorbidities']=0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df.Gender = le.fit_transform(df['Gender'])

# %%
df
# Out:
#       Patient_ID  Age  Gender   BMI Smoking_Status  Family_History Allergies  \
# 0     ASTH100000   52       0  27.6              1               1         3
# 1     ASTH100001   15       1  24.6              1               0         3
# 2     ASTH100002   72       0  17.6              0               0         3
# 3     ASTH100003   61       1  16.8              0               0         0
# 4     ASTH100004   21       1  30.2              0               0         3
# ...          ...  ...     ...   ...            ...             ...       ...
# 9995  ASTH109995   70       1  25.0              0               0         3
# 9996  ASTH109996   78       0  24.8              0               0         2
# 9997  ASTH109997   58       1  30.1              1               1         2
# 9998  ASTH109998   88       0  31.2              1               0         2
# 9999  ASTH109999   13       0  16.4              1               1         0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Patient_ID               10000 non-null  object
#  1   Age                      10000 non-null  int64
#  2   Gender                   10000 non-null  int32
#  3   BMI                      10000 non-null  float64
#  4   Smoking_Status           10000 non-null  object
#  5   Family_History           10000 non-null  int64
#  6   Allergies                10000 non-null  object
#  7   Air_Pollution_Level      10000 non-null  object
#  8   Physical_Activity_Level  10000 non-null  object
#  9   Occupation_Type          10000 non-null  object
#  10  Comorbidities            10000 non-null  object
#  11  Medication_Adherence     10000 non-null  float64
#  12  Number_of_ER_Visits      10000 non-null  int64
#  13  Peak_Expiratory_Flow     10000 non-null  float64
# ...

# %%
df['Smoking_Status'] = df['Smoking_Status'].astype(float)
df['Allergies'] = df['Allergies'].astype(float)
df['Air_Pollution_Level'] = df['Air_Pollution_Level'].astype(float)
df['Physical_Activity_Level'] = df['Physical_Activity_Level'].astype(float)
df['Occupation_Type'] = df['Occupation_Type'].astype(float)
df['Comorbidities'] = df['Comorbidities'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Patient_ID               10000 non-null  object
#  1   Age                      10000 non-null  int64
#  2   Gender                   10000 non-null  int32
#  3   BMI                      10000 non-null  float64
#  4   Smoking_Status           10000 non-null  float64
#  5   Family_History           10000 non-null  int64
#  6   Allergies                10000 non-null  float64
#  7   Air_Pollution_Level      10000 non-null  float64
#  8   Physical_Activity_Level  10000 non-null  float64
#  9   Occupation_Type          10000 non-null  float64
#  10  Comorbidities            10000 non-null  float64
#  11  Medication_Adherence     10000 non-null  float64
#  12  Number_of_ER_Visits      10000 non-null  int64
#  13  Peak_Expiratory_Flow     10000 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# Patient_ID                    0
# Age                           0
# Gender                        0
# BMI                           0
# Smoking_Status                0
# Family_History                0
# Allergies                  2936
# Air_Pollution_Level           0
# Physical_Activity_Level       0
# Occupation_Type               0
# Comorbidities              4967
# Medication_Adherence          0
# Number_of_ER_Visits           0
# Peak_Expiratory_Flow          0
# FeNO_Level                    0
# Has_Asthma                    0
# Asthma_Control_Level       7567
# dtype: int64

# %% [markdown]
# ## Handeling Outliers

# %%
df2=[['Age', 'BMI','Medication_Adherence','Peak_Expiratory_Flow', 'FeNO_Level', 'Has_Asthma']]

# %%
sns.boxplot(df.BMI)
plt.show()

# %%
Q1 = df.BMI.quantile(0.25)
Q3 =df.BMI.quantile(0.75)
IQR = Q3-Q1
print(IQR)
min_limit=Q1 - 1.5*IQR
max_limit=Q3 +1.5*IQR
print("min limit = ",min_limit)
print("max limit = ",max_limit)
df.loc[df['BMI'] > max_limit]
df.loc[df['BMI'] < min_limit]
df.loc[df['BMI'] > max_limit,'BMI']=np.median(df.BMI)
df.loc[df['BMI'] > max_limit,'BMI']=np.median(df.BMI)
sns.boxplot(df.BMI)
plt.show()
# Out:
# 6.799999999999997
# min limit =  11.400000000000006
# max limit =  38.599999999999994

# %%
sns.boxplot(df.Medication_Adherence)
plt.show()

# %%
sns.boxplot(df.Peak_Expiratory_Flow)
plt.show()

# %%
sns.boxplot(df.FeNO_Level)
plt.show()

# %%
Q1 = df.FeNO_Level.quantile(0.25)
Q3 =df.FeNO_Level.quantile(0.75)
IQR = Q3-Q1
print(IQR)
min_limit=Q1 - 1.5*IQR
max_limit=Q3 +1.5*IQR
print("min limit = ",min_limit)
print("max limit = ",max_limit)
df.loc[df['FeNO_Level'] > max_limit]
df.loc[df['FeNO_Level'] < min_limit]
df.loc[df['FeNO_Level'] > max_limit,'FeNO_Level']=np.median(df.FeNO_Level)
df.loc[df['FeNO_Level'] > max_limit,'FeNO_Level']=np.median(df.FeNO_Level)
sns.boxplot(df.FeNO_Level)
plt.show()
# Out:
# 13.5
# min limit =  -2.0500000000000007
# max limit =  51.95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Patient_ID               10000 non-null  object
#  1   Age                      10000 non-null  int64
#  2   Gender                   10000 non-null  object
#  3   BMI                      10000 non-null  float64
#  4   Smoking_Status           10000 non-null  object
#  5   Family_History           10000 non-null  int64
#  6   Allergies                10000 non-null  object
#  7   Air_Pollution_Level      10000 non-null  object
#  8   Physical_Activity_Level  10000 non-null  object
#  9   Occupation_Type          10000 non-null  object
#  10  Comorbidities            10000 non-null  object
#  11  Medication_Adherence     10000 non-null  float64
#  12  Number_of_ER_Visits      10000 non-null  int64
#  13  Peak_Expiratory_Flow     10000 non-null  float64
# ...

# %%
df.drop('Asthma_Control_Level',axis=1, inplace=True)
df.drop('Patient_ID', axis=1, inplace=True)

# %%
df
# Out:
#       Age  Gender   BMI  Smoking_Status  Family_History  Allergies  \
# 0      52       0  27.6             1.0               1        3.0
# 1      15       1  24.6             1.0               0        3.0
# 2      72       0  17.6             0.0               0        3.0
# 3      61       1  16.8             0.0               0        0.0
# 4      21       1  30.2             0.0               0        3.0
# ...   ...     ...   ...             ...             ...        ...
# 9995   70       1  25.0             0.0               0        3.0
# 9996   78       0  24.8             0.0               0        2.0
# 9997   58       1  30.1             1.0               1        2.0
# 9998   88       0  31.2             1.0               0        2.0
# 9999   13       0  16.4             1.0               1        0.0
#
#       Air_Pollution_Level  Physical_Activity_Level  Occupation_Type  \
# 0                     2.0                      2.0              1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      10000 non-null  int64
#  1   Gender                   10000 non-null  int32
#  2   BMI                      10000 non-null  float64
#  3   Smoking_Status           10000 non-null  float64
#  4   Family_History           10000 non-null  int64
#  5   Allergies                10000 non-null  float64
#  6   Air_Pollution_Level      10000 non-null  float64
#  7   Physical_Activity_Level  10000 non-null  float64
#  8   Occupation_Type          10000 non-null  float64
#  9   Comorbidities            10000 non-null  float64
#  10  Medication_Adherence     10000 non-null  float64
#  11  Number_of_ER_Visits      10000 non-null  int64
#  12  Peak_Expiratory_Flow     10000 non-null  float64
#  13  FeNO_Level               10000 non-null  float64
# ...

# %% [markdown]
# ## Feature Selection

# %%
df.head()
# Out:
#    Age  Gender   BMI  Smoking_Status  Family_History  Allergies  \
# 0   52     0.0  27.6               1               1          4
# 1   15     1.0  24.6               1               0          4
# 2   72     0.0  17.6               0               0          4
# 3   61     1.0  16.8               0               0          1
# 4   21     1.0  30.2               0               0          4
#
#    Air_Pollution_Level  Physical_Activity_Level  Occupation_Type  \
# 0                    1                        0                1
# 1                    0                        1                0
# 2                    1                        1                0
# 3                    2                        0                1
# 4                    1                        3                0
#
#    Comorbidities  Medication_Adherence  Number_of_ER_Visits  \
# 0              2                  0.38                    0
# 1              3                  0.60                    2
# ...

# %%
# Checking correlation
corr_data=df[['Age','BMI','Medication_Adherence','Peak_Expiratory_Flow','FeNO_Level']]
corr_data
# Out:
#       Age   BMI  Medication_Adherence  Peak_Expiratory_Flow  FeNO_Level
# 0      52  27.6                  0.38                 421.0        46.0
# 1      15  24.6                  0.60                 297.6        22.9
# 2      72  17.6                  0.38                 303.3        15.3
# 3      61  16.8                  0.60                 438.0        40.1
# 4      21  30.2                  0.82                 535.0        27.7
# ...   ...   ...                   ...                   ...         ...
# 9995   70  25.0                  0.67                 580.6        18.7
# 9996   78  24.8                  0.72                 417.6        40.8
# 9997   58  30.1                  0.28                 459.1        20.3
# 9998   88  31.2                  0.44                 415.9        25.0
# 9999   13  16.4                  0.23                 359.4        23.2
#
# [10000 rows x 5 columns]

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":15})
# Out:
# <Axes: >

# %% [markdown]
# ## Model Creation

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'Smoking_Status', 'Family_History', 'Allergies',
#        'Air_Pollution_Level', 'Physical_Activity_Level', 'Occupation_Type',
#        'Comorbidities', 'Medication_Adherence', 'Number_of_ER_Visits',
#        'Peak_Expiratory_Flow', 'FeNO_Level', 'Has_Asthma'],
#       dtype='object')

# %%
x = df.drop(['Has_Asthma'], axis=1)
y = df['Has_Asthma']

# %%
x.head()
# Out:
#    Age  Gender   BMI  Smoking_Status  Family_History  Allergies  \
# 0   52       0  27.6             1.0               1        3.0
# 1   15       1  24.6             1.0               0        3.0
# 2   72       0  17.6             0.0               0        3.0
# 3   61       1  16.8             0.0               0        0.0
# 4   21       1  30.2             0.0               0        3.0
#
#    Air_Pollution_Level  Physical_Activity_Level  Occupation_Type  \
# 0                  2.0                      2.0              1.0
# 1                  1.0                      1.0              0.0
# 2                  2.0                      1.0              0.0
# 3                  0.0                      2.0              1.0
# 4                  2.0                      0.0              0.0
#
#    Comorbidities  Medication_Adherence  Number_of_ER_Visits  \
# 0            2.0                  0.38                    0
# 1            0.0                  0.60                    2
# ...

# %%
# Scaling Data
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
x_scaled= scalar.fit_transform(x)

# %%
x_scaled
# Out:
# array([[ 0.27558178, -0.95807792,  0.52247923, ..., -0.99547953,
#          0.20626152,  2.12390587],
#        [-1.16678533,  1.04375644, -0.09300355, ...,  0.96431874,
#         -1.05903902, -0.22372854],
#        [ 1.05523967, -0.95807792, -1.52913003, ..., -0.99547953,
#         -1.00059321, -0.99611043],
#        ...,
#        [ 0.50947915,  1.04375644,  1.03538154, ..., -0.99547953,
#          0.59692563, -0.48796445],
#        [ 1.67896599, -0.95807792,  1.26105856, ..., -0.99547953,
#          0.1539679 , -0.01030723],
#        [-1.24475112, -0.95807792, -1.77532314, ..., -0.99547953,
#         -0.42536338, -0.19323979]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,random_state=42)

# %%
x_train
# Out:
# array([[ 0.19761599,  1.04375644,  0.23525393, ..., -0.99547953,
#         -0.23259474,  0.46734999],
#        [-1.67356296, -0.95807792, -0.44177712, ..., -0.0155804 ,
#         -0.29411665,  0.46734999],
#        [-0.42611033,  1.04375644,  0.80970452, ...,  0.96431874,
#         -0.55558475,  0.213277  ],
#        ...,
#        [-0.54305901,  1.04375644, -1.81635533, ..., -0.99547953,
#          0.93529611, -0.48796445],
#        [-0.03628138, -0.95807792,  0.07112519, ..., -0.0155804 ,
#          0.44722232, -0.41682402],
#        [ 0.93829099, -0.95807792,  0.66609187, ..., -0.99547953,
#         -1.26206131,  0.09132196]])

# %%
df.isna().sum()
# Out:
# Age                        0
# Gender                     0
# BMI                        0
# Smoking_Status             0
# Family_History             0
# Allergies                  0
# Air_Pollution_Level        0
# Physical_Activity_Level    0
# Occupation_Type            0
# Comorbidities              0
# Medication_Adherence       0
# Number_of_ER_Visits        0
# Peak_Expiratory_Flow       0
# FeNO_Level                 0
# Has_Asthma                 0
# dtype: int64

# %% [markdown]
# # Logistic Regression Model

# %%
## Step 3 Model creation
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()
clf.fit(x_train,y_train)  ## training
# Out:
# LogisticRegression()

# %%
y_prd_lor=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score,classification_report
# test
accu_scor_lor =  accuracy_score(y_test,y_prd_lor)
accu_scor_lor
# Out:
# 0.8828

# %%
# train
x_prd_lor=clf.predict(x_train)
accu_scor_lor_x =  accuracy_score(y_train,x_prd_lor)
accu_scor_lor_x
# Out:
# 0.8665333333333334
